# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. 이항분포 시뮬레이션 (n=10, p=0.5, size=1000)
binomial_samples = np.random.binomial(n=10, p=0.5, size=1000)

# 2. 평균과 분산 계산
mean_val = binomial_samples.mean()   # TODO
var_val = binomial_samples.var()    # TODO

print("표본 평균:", mean_val)
print("표본 분산:", var_val)

# 3. 히스토그램 시각화
plt.hist(binomial_samples, bins=11, density=True, alpha=0.7)
plt.title("Binomial Distribution Simulation")
plt.show()
# Out:
# 표본 평균: 5.085
# 표본 분산: 2.4697750000000003

# %%
# 1. n=10, p=0.5
samples_n10 = np.random.binomial(n=10, p=0.5, size=1000)

# 2. n=100, p=0.5
samples_n100 = np.random.binomial(n=100, p=0.5, size=1000)   # TODO: n=100일 때 시뮬레이션

# 3. n=1000, p=0.5
samples_n1000 = np.random.binomial(n=1000, p=0.5, size=1000)  # TODO: n=1000일 때 시뮬레이션


# 4. 히스토그램 비교
plt.hist(samples_n10, bins=20, density=True, alpha=0.5, label="n=10")
plt.hist(samples_n100, bins=20, density=True, alpha=0.5, label="n=100")
plt.hist(samples_n1000, bins=20, density=True, alpha=0.5, label="n=1000")
plt.legend()
plt.title("Binomial Distribution with Different n")
plt.show()

# %%
# %pip install scipy
from scipy.stats import norm

# 1. 이항분포 샘플링 (n=100, p=0.5)
binomial_samples = np.random.binomial(n=100, p=0.5, size=1000)

# 2. 정규분포 근사 
mu = binomial_samples.mean()     # TODO: 평균 계산
sigma = binomial_samples.std()  # TODO: 표준편차 계산

x = np.arange(30, 70)
normal_probs = norm.pdf(x, loc=mu, scale=sigma)

# 3. 히스토그램 + 정규분포 곡선 비교
plt.hist(binomial_samples, bins=20, density=True, alpha=0.6, label="Binomial (n=100, p=0.5)")
plt.plot(x, normal_probs, "r-", label="Normal Approximation")
plt.legend()
plt.show()
# Out:
# Requirement already satisfied: scipy in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (1.16.2)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\ssafy\appdata\local\programs\python\python311\lib\site-packages (from scipy) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
